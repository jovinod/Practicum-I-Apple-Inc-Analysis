# %% [markdown]
# ### Look at what community is saying about iphone releases

# %%
import numpy as np
import pandas as pd
import re
import warnings
import textblob
from textblob import TextBlob 
#Visualisation
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from IPython.display import display
from wordcloud import WordCloud, STOPWORDS

#nltk
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
from nltk import tokenize

matplotlib.style.use('ggplot')
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
tweet = pd.read_csv('../../Data/iphone_tweets_2015.csv', encoding = "ISO-8859-1")

# %%
tweet.head()
# Out:
#    user            date  retweets  favorites  \
# 0  user  9/30/2015 5:15         0          0
# 1  user  9/30/2015 5:04         0          1
# 2  user  9/30/2015 5:02         0          0
# 3  user  9/30/2015 4:58         0          0
# 4  user  9/30/2015 4:53         0          1
#
#                                                 text  geo mentions hashtags  \
# 0  Win an # Apple Watch or # iPhone 6s from Macph...  NaN      NaN      # #
# 1  Realifex is Your Life Tracker. Free Yourself f...  NaN      NaN  # # # #
# 2  Choose from tons of cool # iPhone cases at htt...  NaN      NaN        #
# 3  I've received 4917 $ from my friends in associ...  NaN      NaN    # # #
# 4  I'm loving the size of my new # iPhone 6s Plus...  NaN      NaN      # #
#
#             id1                                          permalink
# 0  6.490070e+17  https://twitter.com/agence/status/649007044025...
# 1  6.490040e+17  https://twitter.com/Realifex/status/6490043832...
# ...

# %%
tweet['text'] = tweet['text'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))
tweet['text'] = tweet['text'].apply(lambda x: re.sub('  ', ' ', x))

# %%
tweetContent15 = tweet.filter(['text','date','retweets','favorites'], axis=1)

# %%
tweetContent15[['polarity', 'subjectivity']] = tweetContent15['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
tweetContent15.head()
# Out:
#                                                 text            date  \
# 0  win an apple watch or iphone 6s from macphun a...  9/30/2015 5:15
# 1  realifex is your life tracker free yourself fr...  9/30/2015 5:04
# 2  choose from tons of cool iphone cases at http/...  9/30/2015 5:02
# 3  i've received 4917 from my friends in associat...  9/30/2015 4:58
# 4  i'm loving the size of my new iphone 6s plus r...  9/30/2015 4:53
#
#    retweets  favorites  polarity  subjectivity
# 0         0          0  0.800000      0.400000
# 1         0          1  0.400000      0.800000
# 2         0          0  0.350000      0.650000
# 3         0          0  0.000000      0.000000
# 4         0          1  0.307273      0.520909

# %%
tweet = pd.read_csv('../../Data/iphone_tweets_2016.csv', encoding = "ISO-8859-1")

# %%
tweet.head()
# Out:
#    user            date  retweets  favorites  \
# 0  user  9/30/2016 5:21         0          0
# 1  user  9/30/2016 5:15         0          0
# 2  user  9/30/2016 5:13         0          0
# 3  user  9/30/2016 4:50         0          0
# 4  user  9/30/2016 4:48         0          0
#
#                                                 text  geo mentions  \
# 0  # iphone # recovery iPhone 7 Photo Recovery: H...  NaN      NaN
# 1  Why and how I switched from # Windows to # MAC...  NaN      NaN
# 2  # CarlZeiss lens for # iphone # smartphone & #...  NaN      NaN
# 3  I've completed Bijou from Goa quest in Airport...  NaN      NaN
# 4  Top free # iPhone Business # Apps #18: Sidelin...  NaN      NaN
#
#           hashtags           id1  \
# 0              # #  7.816420e+17
# 1  # # # # # # # #  7.816410e+17
# 2      # # # # # #  7.816400e+17
# 3              # #  7.816350e+17
# 4              NaN           NaN
#
#                                            permalink
# ...

# %%
tweet['text'] = tweet['text'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))
tweet['text'] = tweet['text'].apply(lambda x: re.sub('  ', ' ', x))

# %%
tweetContent16 = tweet.filter(['text','date','retweets','favorites'], axis=1)

# %%
tweetContent16[['polarity', 'subjectivity']] = tweetContent16['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
tweetContent16.head()
# Out:
#                                                 text            date  \
# 0   iphone recovery iphone 7 photo recovery how t...  9/30/2016 5:21
# 1  why and how i switched from windows to mac tec...  9/30/2016 5:15
# 2   carlzeiss lens for iphone smartphone  livestr...  9/30/2016 5:13
# 3  i've completed bijou from goa quest in airport...  9/30/2016 4:50
# 4  top free iphone business apps 18 sideline - 2n...  9/30/2016 4:48
#
#    retweets  favorites  polarity  subjectivity
# 0         0          0       0.0      0.000000
# 1         0          0       0.0      0.000000
# 2         0          0       0.0      0.000000
# 3         0          0       0.0      0.000000
# 4         0          0       0.3      0.433333

# %%
tweet = pd.read_csv('../../Data/iphone_tweets_2017.csv', encoding = "ISO-8859-1")

# %%
tweet.head()
# Out:
#    user            date  retweets  favorites  \
# 0  user  9/30/2017 5:20         0          0
# 1  user  9/30/2017 5:14         0          0
# 2  user  9/30/2017 5:07         0          0
# 3  user  9/30/2017 5:01         0          0
# 4  user  9/30/2017 4:52         0          0
#
#                                                 text  geo mentions hashtags  \
# 0  Converting from Android to iPhone slightly tou...  NaN      NaN  # # # #
# 1  Frugi - Personal Finance Manager zu verfolgen ...  NaN      NaN      NaN
# 2  The new iphone update is preventing me from sc...  NaN      NaN    # # #
# 3  # iPhone # iPad # AppStore Pricedrop Frugi - P...  NaN      NaN    # # #
# 4                                 Photostein" from 5  NaN      NaN      NaN
#
#             id1                                          permalink
# 0  9.139140e+17  https://twitter.com/techvideos_xyz/status/9139...
# 1           NaN                                                NaN
# ...

# %%
tweet['text'] = tweet['text'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))
tweet['text'] = tweet['text'].apply(lambda x: re.sub('  ', ' ', x))

# %%
tweetContent17 = tweet.filter(['text','date','retweets','favorites'], axis=1)

# %%
tweetContent17[['polarity', 'subjectivity']] = tweetContent17['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
tweetContent17.head()
# Out:
#                                                 text            date  \
# 0  converting from android to iphone slightly tou...  9/30/2017 5:20
# 1  frugi - personal finance manager zu verfolgen ...  9/30/2017 5:14
# 2  the new iphone update is preventing me from sc...  9/30/2017 5:07
# 3   iphone ipad appstore pricedrop frugi - person...  9/30/2017 5:01
# 4                                 photostein" from 5  9/30/2017 4:52
#
#    retweets  favorites  polarity  subjectivity
# 0         0          0 -0.166667      0.166667
# 1         0          0  0.000000      0.300000
# 2         0          0  0.136364      0.454545
# 3         0          0  0.000000      0.300000
# 4         0          0  0.000000      0.000000

# %%
tweet = pd.read_csv('../../Data/iphone_tweets_2018.csv', encoding = "ISO-8859-1")

# %%
tweet.head()
# Out:
#    user            date retweets favorites  \
# 0  user  9/30/2018 4:50        0         0
# 1  user  9/30/2018 4:41        0         0
# 2  user  9/30/2018 4:30        1         2
# 3  user  9/30/2018 4:02        0         0
# 4  user  9/30/2018 2:52        0         0
#
#                                                 text  geo mentions  \
# 0  @ AirCanada - is there a way to export my flig...  NaN      @ @
# 1     # TMobile # fail pt1: I have a phone from 2012  NaN      NaN
# 2  56% Off Rose Gold iPhone Xs Max Folio Case! ON...  NaN      NaN
# 3  # apple # iphones experiencing issues all up f...  NaN      NaN
# 4  Here's a big new Legendary card from Hearthsto...  NaN      NaN
#
#             hashtags           id1  \
# 0  # # # # # # # # #  1.046180e+18
# 1                NaN           NaN
# 2                NaN           NaN
# 3              # # #  1.046170e+18
# 4                  #  1.046150e+18
#
# ...

# %%
tweet['text'] = tweet['text'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))
tweet['text'] = tweet['text'].apply(lambda x: re.sub('  ', ' ', x))

# %%
tweetContent18 = tweet.filter(['text','date','retweets','favorites'], axis=1)

# %%
tweetContent18[['polarity', 'subjectivity']] = tweetContent18['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
tweetContent18.head()
# Out:
#                                                 text            date retweets  \
# 0   aircanada - is there a way to export my fligh...  9/30/2018 4:50        0
# 1          tmobile fail pt1 i have a phone from 2012  9/30/2018 4:41        0
# 2  56% off rose gold iphone xs max folio case onl...  9/30/2018 4:30        1
# 3   apple iphones experiencing issues all up from...  9/30/2018 4:02        0
# 4  here's a big new legendary card from hearthsto...  9/30/2018 2:52        0
#
#   favorites  polarity  subjectivity
# 0         0  0.000000      0.000000
# 1         0 -0.500000      0.300000
# 2         2  0.233333      0.766667
# 3         0  0.000000      0.000000
# 4         0  0.284091      0.388636

# %%
tweetContent = pd.concat([tweetContent15,tweetContent16,tweetContent17,tweetContent18])

# %%
tweetContent.to_excel("twitterfinal.xlsx")
